# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Reading the Necessary files

# %%
data=pd.read_csv("hrdata.csv")

# %%
#data2=pd.read_csv("MMix.csv")

# %%
data3=pd.read_csv("iris.csv")

# %%
data.head()
#data2.head()
#data3.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
#ata.drop('Id',axis = 1, inplace = True)

# %% [markdown]
# # Univariate Plots

# %% [markdown]
# # Histogram

# %%
plt.hist(data.Salary, bins = 10, alpha = 0.5, color = "blue", linewidth=3)

#orientation = 'horizontal'
# Out:
# (array([197.,  65.,  32.,   7.,   2.,   3.,   3.,   0.,   1.,   1.]),
#  array([ 45046. ,  65541.4,  86036.8, 106532.2, 127027.6, 147523. ,
#         168018.4, 188513.8, 209009.2, 229504.6, 250000. ]),
#  <BarContainer object of 10 artists>)

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# # Density

# %%
data.Salary.plot(kind='density', ls='--') #style
plt.xlabel("Income")
plt.title("Density Plot for Income")
plt.rcParams['xtick.labelsize']=8
plt.tight_layout()
plt.show()

# %% [markdown]
# # Histogram with Density

# %%
ax = data['Salary'].plot(kind='hist',color='lightblue',ylim=(0,400))
ax2 = data['Salary'].plot(kind='density',secondary_y=True,color='blue', ax=ax)

ax.set_ylabel('No. of Employees')
ax2.set_ylabel('Density')

# For better pdf plots - https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html
# Out:
# Text(0, 0.5, 'Density')

# %%
type(data['Salary'].plot(kind='hist',color='lightblue',ylim=(0,400)))
# Out:
# matplotlib.axes._axes.Axes

# %% [markdown]
# # Boxplot

# %%
plt.boxplot(data['Salary'] ,  patch_artist=True, vert=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22ba171e5f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22ba171eb30>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x22ba171e260>],
#  'medians': [<matplotlib.lines.Line2D at 0x22ba171f070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22ba171f310>],
#  'means': []}

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2)
data.plot(kind='box', color='red', ax=axes, sharex=False)

plt.tight_layout()
plt.get_current_fig_manager().window.showMaximized()  # Optional: maximize the plot window
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       1 import matplotlib.pyplot as plt
#       3 fig, axes = plt.subplots(nrows=2, ncols=2)
# ----> 4 data.plot(kind='box', color='red', ax=axes, sharex=False)
#       6 plt.tight_layout()
#       7 plt.get_current_fig_manager().window.showMaximized()  # Optional: maximize the plot window
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
data.plot(kind='box',  color = 'red', subplots=True, layout=(2,2), sharex=False)
plt.tight_layout()
plt.show()

# %%
bp = plt.boxplot(data['Salary'])
bp

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# rectangular box plot
bplot1 = axes[0].boxplot(data['Age'])
                         
# notch shape box plot
bplot2 = axes[1].boxplot(data['Salary'])

plt.show()
plt.savefig('matplotlib.png',dpi = 200)

# %% [markdown]
# # Bar Chart

# %%
data3.columns

# %%
plt.bar(data3['Species'], data3['SepalLengthCm'], width = 0.3, color = 'pink',  align='center')

plt.bar(data3['Species'], data3['SepalWidthCm'], width = 0.3, color = 'lightblue',  align='center')

plt.legend(loc=1)
plt.tight_layout()
plt.show()

# %%
plt.barh(data['Gender'], data['Income'], color = 'pink')

# %% [markdown]
# # Line Plot

# %%
plt.plot(data2['NewVolSales'])
plt.xlabel("Week")
plt.ylabel("Volume Sales in thousands")
plt.title("Volume Sales")

# %%
plt.plot(data2['NewVolSales'], c = 'M', ls = "--", marker = "s", ms = 6)
plt.xticks(rotation = 'vertical')
plt.xlabel('Volume Sales in 1000 units')
plt.show()

# %%
fig, ax1 = plt.subplots()

ax1.plot(data2['NewVolSales'])
ax1.set_xlabel('time (w)')

# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Volume Sales')

ax2 = ax1.twinx()
ax2.plot(data2['Radio '], 'r')
ax2.set_ylabel('Radio')

fig.tight_layout()
plt.show()

# %% [markdown]
# # Bivariate Plots

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(x=data['Age'],y = data['Income'], color = "magenta", alpha = 0.5)

plt.title('Relationship Between Age and Income')
plt.xlabel('Age')
plt.ylabel('Income')
